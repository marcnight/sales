# %%
#Importando pandas e definindo o dataframe

import pandas as pd

df = pd.read_excel("sales_data_with_dates.xlsx")

# %%
#Verificando os dados para anlise inicial

df.head(10)
# Out:
#    data_venda  numero_nota codigo_produto      descricao_produto  \
# 0  02/07/2023            1           P008  Hidróxido de Potássio
# 1  02/06/2023            2           P009                 Amônia
# 2  27/02/2022            3           P007     Hidróxido de Sódio
# 3  13/10/2023            4           P004                Metanol
# 4  03/08/2023            5           P008  Hidróxido de Potássio
# 5  11/10/2022            6           P003                 Etanol
# 6  26/04/2022            7           P010                  Cloro
# 7  13/08/2022            8           P002                Benzeno
# 8  10/03/2023            9           P012                  Fenol
# 9  10/02/2023           10           P007     Hidróxido de Sódio
#
#   codigo_cliente descricao_cliente  valor_unitario_produto  \
# 0           C002       Higiene Pro                   95.13
# 1           C012        SaúdeVital                   87.20
# 2           C009     Saúde Suprema                   81.89
# ...

# %%
#Visualizando os valores nulos

df.isnull().sum()
# Out:
# data_venda                          0
# numero_nota                         0
# codigo_produto                      0
# descricao_produto                   0
# codigo_cliente                      0
# descricao_cliente                   0
# valor_unitario_produto              0
# quantidade_vendida_produto          0
# valor_total                         0
# custo_da_venda                      0
# valor_tabela_de_preco_do_produto    0
# dtype: int64

# %%
#Verificando os tipos primitivos de cada coluna

df.dtypes
# Out:
# data_venda                           object
# numero_nota                           int64
# codigo_produto                       object
# descricao_produto                    object
# codigo_cliente                       object
# descricao_cliente                    object
# valor_unitario_produto              float64
# quantidade_vendida_produto            int64
# valor_total                         float64
# custo_da_venda                      float64
# valor_tabela_de_preco_do_produto      int64
# dtype: object
